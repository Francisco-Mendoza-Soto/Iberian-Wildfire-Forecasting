# %%
import cdsapi
from pathlib import Path
import xarray as xr, numpy as np
import subprocess, sys

# %% [markdown]
# # Monthly CDS download

# %%
c = cdsapi.Client()
out = Path("data/era5_monthly"); out.mkdir(parents=True, exist_ok=True)

AREA = [44.0, -10.0, 36.25, 3.25]   # N, W, S, E -> 32 lat x 54 lon
GRID = [0.25, 0.25]

for year in range(2000, 2026):
    temperature_target = out / f"era5_monthly_temperature_{year}.nc"
    precipitation_target = out / f"era5_monthly_precipitation_{year}.nc"
    
    if temperature_target.exists() and precipitation_target.exists():
        print(f"skip {year}"); continue
    try:
        c.retrieve(
            "reanalysis-era5-single-levels-monthly-means",
            {
                "product_type": "monthly_averaged_reanalysis",
                "variable": ["2m_temperature"],
                "year": str(year),
                "month": [f"{m:02d}" for m in range(1, 13)],
                "time": "00:00",
                "area": AREA,
                "grid": GRID,
                "data_format": "netcdf",
            },
            str(temperature_target),
        )
        c.retrieve(
            "reanalysis-era5-single-levels-monthly-means",
            {
                "product_type": "monthly_averaged_reanalysis",
                "variable": ["total_precipitation"],
                "year": str(year),
                "month": [f"{m:02d}" for m in range(1, 13)],
                "time": "00:00",
                "area": AREA,
                "grid": GRID,
                "data_format": "netcdf",
            },
            str(precipitation_target),
        )

    except Exception as e:
        print(f"FAILED {year}: {e}")
# Out:
# 2026-05-04 09:24:29,794 INFO Request ID is 36a523c4-98cf-4184-b1b0-5d8f4a6a255f
# 2026-05-04 09:24:29,885 INFO status has been updated to accepted
# 2026-05-04 09:24:43,520 INFO status has been updated to running
# 2026-05-04 09:24:51,610 INFO status has been updated to successful
# a53061d701f2597a5ec9a248da4f16b9.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:24:53,610 INFO Request ID is 1973b665-5feb-4374-be02-91397ff3ed33
# 2026-05-04 09:24:53,908 INFO status has been updated to accepted
# 2026-05-04 09:25:07,828 INFO status has been updated to running
# 2026-05-04 09:25:15,496 INFO status has been updated to successful
# 839aea25ac798e4eb84e8c50b276915b.nc:   0%|          | 0.00/58.8k [00:00<?, ?B/s]
# 2026-05-04 09:25:17,030 INFO Request ID is 1d2ae7ed-ebae-4b18-af34-6caeeedf0a37
# 2026-05-04 09:25:17,109 INFO status has been updated to accepted
# 2026-05-04 09:25:30,723 INFO status has been updated to running
# 2026-05-04 09:25:38,426 INFO status has been updated to successful
# c751433c2b6e2eab2f4433da1450075f.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:25:40,121 INFO Request ID is 96d91fda-1cd6-4559-a5b8-e1ddb78a93f0
# 2026-05-04 09:25:40,215 INFO status has been updated to accepted
# 2026-05-04 09:25:53,842 INFO status has been updated to running
# 2026-05-04 09:26:01,523 INFO status has been updated to successful
# efd2bffcf92f2f6e7a92160335677121.nc:   0%|          | 0.00/59.3k [00:00<?, ?B/s]
# 2026-05-04 09:26:02,945 INFO Request ID is 019c3dfc-4b15-41c5-8573-c2a7ac5fed7f
# 2026-05-04 09:26:03,036 INFO status has been updated to accepted
# 2026-05-04 09:26:17,025 INFO status has been updated to running
# 2026-05-04 09:26:24,734 INFO status has been updated to successful
# 91a2f404e0ffeac6f23d1c8565b16956.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:26:26,369 INFO Request ID is bfd3dc70-c2e6-4c32-97a1-113fb30e67f9
# 2026-05-04 09:26:26,452 INFO status has been updated to accepted
# 2026-05-04 09:26:40,014 INFO status has been updated to running
# 2026-05-04 09:26:47,698 INFO status has been updated to successful
# 3a7904b43472f49aa28af3c197141392.nc:   0%|          | 0.00/59.4k [00:00<?, ?B/s]
# 2026-05-04 09:26:49,319 INFO Request ID is c053bf67-292a-43ab-915c-7a65cf759a5a
# 2026-05-04 09:26:49,443 INFO status has been updated to accepted
# 2026-05-04 09:27:10,814 INFO status has been updated to successful
# 207259e2a5813cfde019733a909db8ef.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:27:12,367 INFO Request ID is 8532172d-ded2-4ab6-9558-55d5b6c41a14
# 2026-05-04 09:27:12,455 INFO status has been updated to accepted
# 2026-05-04 09:27:26,370 INFO status has been updated to running
# 2026-05-04 09:27:34,046 INFO status has been updated to successful
# f3797bdc415327d5830cc2601237fc3c.nc:   0%|          | 0.00/59.1k [00:00<?, ?B/s]
# 2026-05-04 09:27:35,354 INFO Request ID is f2f7787f-3476-4a26-9f08-218a8b763fb7
# 2026-05-04 09:27:35,429 INFO status has been updated to accepted
# 2026-05-04 09:27:56,737 INFO status has been updated to running
# 2026-05-04 09:28:08,197 INFO status has been updated to successful
# 988749044de192d9576fd79e07c8d276.nc:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# 2026-05-04 09:28:09,823 INFO Request ID is 60b8ceac-83b3-4925-a67c-a019ecac472d
# 2026-05-04 09:28:09,895 INFO status has been updated to accepted
# 2026-05-04 09:28:31,299 INFO status has been updated to successful
# 5e18c8d757f61b5329c8155868788dd8.nc:   0%|          | 0.00/59.4k [00:00<?, ?B/s]
# 2026-05-04 09:28:32,870 INFO Request ID is f8ae9d0b-f34b-4f98-aa90-4cc8f26ce078
# 2026-05-04 09:28:32,946 INFO status has been updated to accepted
# 2026-05-04 09:28:54,278 INFO status has been updated to running
# 2026-05-04 09:29:05,746 INFO status has been updated to successful
# 4a966b6461298c5bd5d354e9bb50f0bf.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:29:07,249 INFO Request ID is 3702f88a-7d8a-45ae-b2e3-bc06599d0f1b
# 2026-05-04 09:29:07,324 INFO status has been updated to accepted
# 2026-05-04 09:29:40,060 INFO status has been updated to successful
# 90e41f8962014c78874f5aaad4cffc12.nc:   0%|          | 0.00/58.4k [00:00<?, ?B/s]
# 2026-05-04 09:29:42,838 INFO Request ID is 0f808726-e23c-4d0e-8a24-1f417c165b08
# 2026-05-04 09:29:42,909 INFO status has been updated to accepted
# 2026-05-04 09:29:56,729 INFO status has been updated to running
# 2026-05-04 09:30:04,394 INFO status has been updated to successful
# 58e0602e57293a854e6c3087f02c5dac.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:30:06,065 INFO Request ID is 0d737c0b-b988-4798-9ca7-03e4aa2becb6
# 2026-05-04 09:30:06,158 INFO status has been updated to accepted
# 2026-05-04 09:30:21,865 INFO status has been updated to running
# 2026-05-04 09:30:29,551 INFO status has been updated to successful
# f7baedb4875d50bfe781d200033c65e1.nc:   0%|          | 0.00/59.6k [00:00<?, ?B/s]
# 2026-05-04 09:30:31,086 INFO Request ID is f9a54ca3-a7c4-4535-99bf-8f4a4ac8367b
# 2026-05-04 09:30:31,161 INFO status has been updated to accepted
# 2026-05-04 09:31:05,421 INFO status has been updated to successful
# de2de725e06a58aa1c00a02d640b814e.nc:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# 2026-05-04 09:31:06,954 INFO Request ID is 1b4c9ee2-721c-47ea-bd77-d276817de531
# 2026-05-04 09:31:07,023 INFO status has been updated to accepted
# 2026-05-04 09:31:20,722 INFO status has been updated to successful
# c5ad9534bb1ccaccc3c565b0a9641654.nc:   0%|          | 0.00/60.0k [00:00<?, ?B/s]
# 2026-05-04 09:31:23,883 INFO Request ID is c127e624-ef66-4ff0-871f-5323b655c309
# 2026-05-04 09:31:23,959 INFO status has been updated to accepted
# 2026-05-04 09:31:45,401 INFO status has been updated to successful
# 9985b7b9c08d669b34cb7b1528ba167e.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:31:47,507 INFO Request ID is f2a81623-30c5-43b8-8cf0-d70adb89c138
# 2026-05-04 09:31:47,581 INFO status has been updated to accepted
# 2026-05-04 09:32:02,509 INFO status has been updated to running
# 2026-05-04 09:32:10,183 INFO status has been updated to successful
# 46dc2f3ec820ad8f73a9b96ae0d33b52.nc:   0%|          | 0.00/60.0k [00:00<?, ?B/s]
# 2026-05-04 09:32:11,737 INFO Request ID is 89071cda-aff6-4d9f-a001-f2338c3486bc
# 2026-05-04 09:32:11,829 INFO status has been updated to accepted
# 2026-05-04 09:32:25,994 INFO status has been updated to running
# 2026-05-04 09:32:33,680 INFO status has been updated to successful
# e0262e1bb4ff0fa2ea1de49e1655d1d1.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:32:35,045 INFO Request ID is 5177ef76-7f1b-44cd-b45b-952ee5d720f7
# 2026-05-04 09:32:35,135 INFO status has been updated to accepted
# 2026-05-04 09:32:48,933 INFO status has been updated to running
# 2026-05-04 09:32:56,597 INFO status has been updated to successful
# 3b8476ddca1a2a4ac920f351ac85d954.nc:   0%|          | 0.00/59.8k [00:00<?, ?B/s]
# 2026-05-04 09:32:58,149 INFO Request ID is c915bd5b-39f6-4694-aa78-8db7ce9d29c7
# 2026-05-04 09:32:58,239 INFO status has been updated to accepted
# 2026-05-04 09:33:30,952 INFO status has been updated to successful
# a7f5ec1a0185536b911cf076f1e6c511.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:33:32,418 INFO Request ID is c5cfc2f3-0ae7-4d73-b673-29a07f4f2939
# 2026-05-04 09:33:32,490 INFO status has been updated to accepted
# 2026-05-04 09:33:53,768 INFO status has been updated to running
# 2026-05-04 09:34:05,235 INFO status has been updated to successful
# f1737fc51c8ff21ee6941330fcb6dfef.nc:   0%|          | 0.00/59.9k [00:00<?, ?B/s]
# 2026-05-04 09:34:06,729 INFO Request ID is 5b923eb8-c345-47dd-9c97-345b31507cef
# 2026-05-04 09:34:06,831 INFO status has been updated to accepted
# 2026-05-04 09:34:39,586 INFO status has been updated to successful
# cdc3d128ad8273929c070a4639d48dfa.nc:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# 2026-05-04 09:34:41,009 INFO Request ID is 3e5e546f-3f9a-46eb-9e02-c191510fa552
# 2026-05-04 09:34:41,085 INFO status has been updated to accepted
# 2026-05-04 09:34:56,778 INFO status has been updated to successful
# f94f1346b68982b9f1d21a8a0dd10b66.nc:   0%|          | 0.00/59.9k [00:00<?, ?B/s]
# 2026-05-04 09:34:58,213 INFO Request ID is 1d986a10-36b5-4142-a94b-fb9b2a325bf2
# 2026-05-04 09:34:58,304 INFO status has been updated to accepted
# 2026-05-04 09:35:19,598 INFO status has been updated to running
# 2026-05-04 09:35:31,083 INFO status has been updated to successful
# eb29c1b2aafabb5d8585b6a796f4eb98.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:35:32,776 INFO Request ID is 0cf23dc1-0eaa-491c-81d2-77ad919a7af5
# 2026-05-04 09:35:33,075 INFO status has been updated to accepted
# 2026-05-04 09:35:54,364 INFO status has been updated to successful
# 3a58d842e2e4c529144a9c70cb930b26.nc:   0%|          | 0.00/59.2k [00:00<?, ?B/s]
# 2026-05-04 09:35:55,940 INFO Request ID is cebb9e8f-25a5-438d-af0c-82739cc8f750
# 2026-05-04 09:35:56,013 INFO status has been updated to accepted
# 2026-05-04 09:36:17,271 INFO status has been updated to successful
# 599740b42ebcaa230771dbd4a6973fd7.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:36:18,737 INFO Request ID is e1222391-ff93-46e4-93e0-a01411837652
# 2026-05-04 09:36:18,827 INFO status has been updated to accepted
# 2026-05-04 09:36:40,278 INFO status has been updated to running
# 2026-05-04 09:36:51,741 INFO status has been updated to successful
# 6dac1e9ea3aba696c5659d276569dcb5.nc:   0%|          | 0.00/59.8k [00:00<?, ?B/s]
# 2026-05-04 09:36:53,201 INFO Request ID is 0b957021-5f4c-4f1b-a9d6-49abb2b404dc
# 2026-05-04 09:36:53,286 INFO status has been updated to accepted
# 2026-05-04 09:37:14,797 INFO status has been updated to running
# 2026-05-04 09:37:26,261 INFO status has been updated to successful
# bf6cc0cd23fd7017c1384b547b29ff9a.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:37:27,860 INFO Request ID is 352eacc9-87be-4da8-a47a-90feb0094c1f
# 2026-05-04 09:37:27,952 INFO status has been updated to accepted
# 2026-05-04 09:37:49,238 INFO status has been updated to running
# 2026-05-04 09:38:00,702 INFO status has been updated to successful
# 867511c14f5d1ca8091acc37058b0b94.nc:   0%|          | 0.00/60.0k [00:00<?, ?B/s]
# 2026-05-04 09:38:02,630 INFO Request ID is 9128481f-4688-4335-9291-aac697ee4cd0
# 2026-05-04 09:38:02,734 INFO status has been updated to accepted
# 2026-05-04 09:38:24,774 INFO status has been updated to running
# 2026-05-04 09:38:36,250 INFO status has been updated to successful
# 244aefd6824a26d7530eaec6dd6d77f1.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:38:37,824 INFO Request ID is 19e0ab85-9e29-400a-b4e8-91f785a9358b
# 2026-05-04 09:38:37,910 INFO status has been updated to accepted
# 2026-05-04 09:38:59,193 INFO status has been updated to running
# 2026-05-04 09:39:10,655 INFO status has been updated to successful
# 4682b92b1c3e68e279b9fbecbc41f8e5.nc:   0%|          | 0.00/59.3k [00:00<?, ?B/s]
# 2026-05-04 09:39:12,425 INFO Request ID is 99bb4d12-819a-4547-a43e-5afc3875f432
# 2026-05-04 09:39:12,502 INFO status has been updated to accepted
# 2026-05-04 09:39:33,855 INFO status has been updated to running
# 2026-05-04 09:39:45,325 INFO status has been updated to successful
# e17e0b34a0806a2fbb11ae112cb85cfd.nc:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# 2026-05-04 09:39:46,947 INFO Request ID is 48eaa91a-0bf6-438f-858f-2b356abee468
# 2026-05-04 09:39:47,024 INFO status has been updated to accepted
# 2026-05-04 09:40:08,322 INFO status has been updated to running
# 2026-05-04 09:40:19,803 INFO status has been updated to successful
# b37cac4526b9dd66c7d2afc1c3900d40.nc:   0%|          | 0.00/59.4k [00:00<?, ?B/s]
# 2026-05-04 09:40:21,309 INFO Request ID is 77de21fb-a682-4e0c-b2c9-adedaf645f25
# 2026-05-04 09:40:21,385 INFO status has been updated to accepted
# 2026-05-04 09:40:37,105 INFO status has been updated to successful
# 4d5dee89b69b7e3ba98ac65f46b89d47.nc:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# 2026-05-04 09:40:38,735 INFO Request ID is 3997ef5f-1cc1-4384-a722-cc138a2b16c7
# 2026-05-04 09:40:38,804 INFO status has been updated to accepted
# 2026-05-04 09:41:00,585 INFO status has been updated to successful
# 575595e911cf4bc6a23f8823179f7919.nc:   0%|          | 0.00/58.9k [00:00<?, ?B/s]
# 2026-05-04 09:41:02,272 INFO Request ID is 0a9d80f2-c29c-4bd2-a996-dc5ff00e0ce0
# 2026-05-04 09:41:02,361 INFO status has been updated to accepted
# 2026-05-04 09:41:25,010 INFO status has been updated to successful
# 9f875ece0d693ff22e08a56019869587.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:41:26,445 INFO Request ID is 5f5fb3cc-c5df-45fb-819d-54eaedd33625
# 2026-05-04 09:41:26,515 INFO status has been updated to accepted
# 2026-05-04 09:41:41,621 INFO status has been updated to running
# 2026-05-04 09:41:49,522 INFO status has been updated to successful
# 4324f4cd2736c9bf05f097dfe06fbebd.nc:   0%|          | 0.00/60.7k [00:00<?, ?B/s]
# 2026-05-04 09:41:51,011 INFO Request ID is f8914fb4-46a3-4ad2-863c-d80e4a507f16
# 2026-05-04 09:41:51,092 INFO status has been updated to accepted
# 2026-05-04 09:42:04,829 INFO status has been updated to running
# 2026-05-04 09:42:12,502 INFO status has been updated to successful
# 8ca285669c548dc2582910c91b5c7ada.nc:   0%|          | 0.00/60.3k [00:00<?, ?B/s]
# 2026-05-04 09:42:13,735 INFO Request ID is 88fcb929-e564-4369-acb2-d6c46b1886f4
# 2026-05-04 09:42:13,800 INFO status has been updated to accepted
# 2026-05-04 09:42:27,410 INFO status has been updated to running
# 2026-05-04 09:42:35,075 INFO status has been updated to successful
# e7b036dbe762e55e98d4853c4875ac94.nc:   0%|          | 0.00/59.4k [00:00<?, ?B/s]
# 2026-05-04 09:42:36,309 INFO Request ID is 21244706-1640-46d7-9f03-ed331e8e9172
# 2026-05-04 09:42:36,388 INFO status has been updated to accepted
# 2026-05-04 09:42:50,298 INFO status has been updated to running
# 2026-05-04 09:42:57,965 INFO status has been updated to successful
# 1733f453c0c6a165ee60fb779238fdbc.nc:   0%|          | 0.00/60.4k [00:00<?, ?B/s]
# 2026-05-04 09:42:59,290 INFO Request ID is 3d8f538c-b7f5-411c-8c5b-c8f23586b607
# 2026-05-04 09:42:59,364 INFO status has been updated to accepted
# 2026-05-04 09:43:20,585 INFO status has been updated to running
# 2026-05-04 09:43:49,235 INFO status has been updated to successful
# 1c5281cd7f85b8161ebff6081fc2f24a.nc:   0%|          | 0.00/58.9k [00:00<?, ?B/s]
# 2026-05-04 09:43:50,682 INFO Request ID is f6144153-9116-4d1e-af28-162da15167e1
# 2026-05-04 09:43:50,767 INFO status has been updated to accepted
# 2026-05-04 09:44:04,379 INFO status has been updated to running
# 2026-05-04 09:44:12,076 INFO status has been updated to successful
# e58685c3aa51e0b1d1f0a17e8a855c2c.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:44:13,209 INFO Request ID is bf8441c8-cb77-417e-a225-4f84b45c7fcd
# 2026-05-04 09:44:13,297 INFO status has been updated to accepted
# 2026-05-04 09:45:03,196 INFO status has been updated to running
# 2026-05-04 09:45:28,903 INFO status has been updated to successful
# 75104666bfd1e75ba64d92d28f4af0a4.nc:   0%|          | 0.00/60.0k [00:00<?, ?B/s]
# 2026-05-04 09:45:30,157 INFO Request ID is 58ee2be7-4135-4153-a73d-b32568cdba24
# 2026-05-04 09:45:30,247 INFO status has been updated to accepted
# 2026-05-04 09:45:55,392 INFO status has been updated to successful
# 83af5b64869dfa701f95697d3af47573.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:45:56,780 INFO Request ID is f26b2d5d-7548-4ebe-96cb-8eaa51654942
# 2026-05-04 09:45:56,909 INFO status has been updated to accepted
# 2026-05-04 09:46:18,236 INFO status has been updated to successful
# 401c873d38c8c9bcb625ad6319e3e06b.nc:   0%|          | 0.00/59.5k [00:00<?, ?B/s]
# 2026-05-04 09:46:19,490 INFO Request ID is 2ee4f901-dde8-4d71-9189-e9b0f75cc1a2
# 2026-05-04 09:46:19,564 INFO status has been updated to accepted
# 2026-05-04 09:46:41,283 INFO status has been updated to running
# 2026-05-04 09:46:52,762 INFO status has been updated to successful
# 52b11d3be6ad294ce02ab072acb6e34.nc:   0%|          | 0.00/60.6k [00:00<?, ?B/s]
# 2026-05-04 09:46:53,929 INFO Request ID is 19789b44-df57-4dae-b0f7-1782a0c542a0
# 2026-05-04 09:46:54,021 INFO status has been updated to accepted
# 2026-05-04 09:47:16,204 INFO status has been updated to running
# 2026-05-04 09:47:27,732 INFO status has been updated to successful
# 25d7cef6801b55c5c48b6b189d28e641.nc:   0%|          | 0.00/59.7k [00:00<?, ?B/s]
# 2026-05-04 09:47:29,073 INFO Request ID is 66802572-6946-4017-a86f-db19eacb2b8f
# 2026-05-04 09:47:29,144 INFO status has been updated to accepted
# 2026-05-04 09:47:45,760 INFO status has been updated to running
# 2026-05-04 09:47:53,446 INFO status has been updated to successful
# 40b3179ac95b31a5094b01aca66712ef.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:47:54,635 INFO Request ID is 3b09f1e4-0e65-46b1-96e0-a112ea79b9e2
# 2026-05-04 09:47:54,723 INFO status has been updated to accepted
# 2026-05-04 09:48:08,609 INFO status has been updated to running
# 2026-05-04 09:48:16,282 INFO status has been updated to successful
# 8e640e41a2f75faad64c03b4659c46bb.nc:   0%|          | 0.00/59.6k [00:00<?, ?B/s]
# 2026-05-04 09:48:17,455 INFO Request ID is 3b41e64c-dd84-4294-a1b6-adbc09d08f84
# 2026-05-04 09:48:17,539 INFO status has been updated to accepted
# 2026-05-04 09:48:31,201 INFO status has been updated to running
# 2026-05-04 09:48:38,871 INFO status has been updated to successful
# e19dd2e209bc5e244f7181324b2e80ef.nc:   0%|          | 0.00/60.5k [00:00<?, ?B/s]
# 2026-05-04 09:48:40,066 INFO Request ID is a9799c5c-e098-4405-af77-ae38b15a02e1
# 2026-05-04 09:48:40,137 INFO status has been updated to accepted
# 2026-05-04 09:48:54,178 INFO status has been updated to successful
# a50073fca5684d740d3097cf40438556.nc:   0%|          | 0.00/60.1k [00:00<?, ?B/s]

# %% [markdown]
# # Hourly CDS download

# %%
c = cdsapi.Client()
out = Path("data/era5_3hourly"); out.mkdir(parents=True, exist_ok=True)

AREA = [44.0, -10.0, 36.25, 3.25]
GRID = [0.25, 0.25]
TIMES = ["00:00", "03:00", "06:00", "09:00",
         "12:00", "15:00", "18:00", "21:00"]
DAYS  = [f"{d:02d}" for d in range(1, 32)]
VARS  = [
    "2m_temperature",
    "2m_dewpoint_temperature",
    "10m_u_component_of_wind",
    "10m_v_component_of_wind",
]

for year in range(2000, 2026):
    for month in range(1, 13):
        target = out / f"era5_3h_surface_{year}_{month:02d}.nc"
        if target.exists():
            continue
        try:
            c.retrieve(
                "reanalysis-era5-single-levels",
                {
                    "product_type": "reanalysis",
                    "variable": VARS,
                    "year": str(year),
                    "month": f"{month:02d}",
                    "day": DAYS,
                    "time": TIMES,
                    "area": AREA,
                    "grid": GRID,
                    "data_format": "netcdf",
                },
                str(target),
            )
        except Exception as e:
            print(f"FAILED {year}-{month:02d}: {e}")
# Out:
# 2026-05-03 10:49:36,385 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:49:36,385 INFO Request ID is 2c5edc12-76d0-44eb-a9e1-1f673fd5d6be
# 2026-05-03 10:49:36,472 INFO status has been updated to accepted
# 2026-05-03 10:49:57,807 INFO status has been updated to running
# 2026-05-03 10:50:52,161 INFO status has been updated to successful
# d8ccd3873dfe0006a553a0836b66593c.nc:   0%|          | 0.00/3.37M [00:00<?, ?B/s]
# 2026-05-03 10:50:54,176 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:50:54,177 INFO Request ID is 09a98b43-766d-4b0a-bf25-7218e31faaa1
# 2026-05-03 10:50:54,280 INFO status has been updated to accepted
# 2026-05-03 10:51:15,564 INFO status has been updated to running
# 2026-05-03 10:51:44,273 INFO status has been updated to successful
# fbe10d57cf10917ea9decfca39255f16.nc:   0%|          | 0.00/3.04M [00:00<?, ?B/s]
# 2026-05-03 10:51:46,555 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:51:46,557 INFO Request ID is e6142732-6e4b-48ad-aa40-484069bfd034
# 2026-05-03 10:51:46,626 INFO status has been updated to accepted
# 2026-05-03 10:52:07,832 INFO status has been updated to running
# 2026-05-03 10:52:36,594 INFO status has been updated to successful
# ef12e308b490b08f7cd0baea2eb5e067.nc:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# 2026-05-03 10:52:38,574 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:52:38,575 INFO Request ID is e16dc9b4-3b28-41dd-ad1a-f049f0dacf8c
# 2026-05-03 10:52:38,740 INFO status has been updated to accepted
# 2026-05-03 10:53:00,155 INFO status has been updated to running
# 2026-05-03 10:54:33,051 INFO status has been updated to successful
# d9e5c122b3adda2086af093445a07090.nc:   0%|          | 0.00/3.25M [00:00<?, ?B/s]
# 2026-05-03 10:54:35,134 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:54:35,137 INFO Request ID is 4e5ea3f8-5260-4c20-af8e-5911c2dd393f
# 2026-05-03 10:54:35,230 INFO status has been updated to accepted
# 2026-05-03 10:54:56,518 INFO status has been updated to running
# 2026-05-03 10:55:50,866 INFO status has been updated to successful
# d91ae093e41e03af03b9c57d5e2d590b.nc:   0%|          | 0.00/3.37M [00:00<?, ?B/s]
# 2026-05-03 10:55:52,931 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:55:52,932 INFO Request ID is 04cdbb67-b8b5-41ca-8b0b-2c80147b6693
# 2026-05-03 10:55:53,021 INFO status has been updated to accepted
# 2026-05-03 10:56:14,413 INFO status has been updated to running
# 2026-05-03 10:57:08,938 INFO status has been updated to successful
# 37788ce5bbf8258173cd966b9b663bf8.nc:   0%|          | 0.00/3.29M [00:00<?, ?B/s]
# 2026-05-03 10:57:11,102 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:57:11,106 INFO Request ID is a9e0b68e-518a-4a30-8bf1-17512df573b2
# 2026-05-03 10:57:11,191 INFO status has been updated to accepted
# 2026-05-03 10:57:32,802 INFO status has been updated to running
# 2026-05-03 10:58:27,134 INFO status has been updated to successful
# 5c49d70c858ec0017dea873221f5dcdf.nc:   0%|          | 0.00/3.39M [00:00<?, ?B/s]
# 2026-05-03 10:58:29,408 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:58:29,409 INFO Request ID is 8dd16565-c12d-441c-824e-5cb136aa02f9
# 2026-05-03 10:58:29,491 INFO status has been updated to accepted
# 2026-05-03 10:58:43,138 INFO status has been updated to running
# 2026-05-03 10:59:45,123 INFO status has been updated to successful
# ecebf077557e6e93948f2b86aeaf09ba.nc:   0%|          | 0.00/3.39M [00:00<?, ?B/s]
# 2026-05-03 10:59:47,090 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 10:59:47,091 INFO Request ID is 5aa691c2-58fd-4aa6-86aa-86970db03d58
# 2026-05-03 10:59:47,299 INFO status has been updated to accepted
# 2026-05-03 11:00:00,870 INFO status has been updated to running
# 2026-05-03 11:01:03,229 INFO status has been updated to successful
# 8a2e7d114d19973df9dbbb304fc36315.nc:   0%|          | 0.00/3.27M [00:00<?, ?B/s]
# 2026-05-03 11:01:06,593 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 11:01:06,594 INFO Request ID is 991432f6-8537-4dc4-94d3-9d54c62d7a49
# 2026-05-03 11:01:06,690 INFO status has been updated to accepted
# 2026-05-03 11:01:27,966 INFO status has been updated to running
# 2026-05-03 11:02:22,316 INFO status has been updated to successful
# ded68ee162e5181d59dd8e1344dcf2b8.nc:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# 2026-05-03 11:02:24,459 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 11:02:24,460 INFO Request ID is 4ccea2df-e3b2-4048-a45a-f90cbe9654ab
# 2026-05-03 11:02:25,811 INFO status has been updated to accepted
# 2026-05-03 11:02:47,042 INFO status has been updated to running
# 2026-05-03 11:03:41,371 INFO status has been updated to successful
# d3f7368949c138f752d0f4d0c3a3a500.nc:   0%|          | 0.00/3.27M [00:00<?, ?B/s]
# 2026-05-03 11:03:43,610 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 11:03:43,611 INFO Request ID is 5bcb882d-ff09-43c7-afec-5a33141c3ff0
# 2026-05-03 11:03:43,689 INFO status has been updated to accepted
# 2026-05-03 11:03:57,655 INFO status has been updated to running
# 2026-05-03 11:04:33,968 INFO status has been updated to successful
# f6e09f74b18cfa7f5a5eed95093705ac.nc:   0%|          | 0.00/3.35M [00:00<?, ?B/s]

# %% [markdown]
# # CDS static land-sea mask

# %%
c = cdsapi.Client()
out = Path("data/era5_static"); out.mkdir(parents=True, exist_ok=True)

AREA = [44.0, -10.0, 36.25, 3.25]
GRID = [0.25, 0.25]

target = out / "era5_lsm.nc"
if not target.exists():
    c.retrieve(
        "reanalysis-era5-single-levels",
        {
            "product_type": "reanalysis",
            "variable": "land_sea_mask",
            "year": "2020",
            "month": "01",
            "day": "01",
            "time": "00:00",
            "area": AREA,
            "grid": GRID,
            "data_format": "netcdf",
        },
        str(target),
    )
# Out:
# 2026-05-03 11:33:38,911 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-03 11:33:38,915 INFO Request ID is 5dd2a169-a61c-4415-9a42-e060212cb462
# 2026-05-03 11:33:39,002 INFO status has been updated to accepted
# 2026-05-03 11:34:00,273 INFO status has been updated to successful
# cbc36450584bc3b819b1c54188ea1688.nc:   0%|          | 0.00/28.7k [00:00<?, ?B/s]

# %% [markdown]
# # Preprocess hourly data to calculate VPD

# %%
def es(T_C):  # Tetens, hPa
    return 6.1078 * np.exp(17.27 * T_C / (T_C + 237.3))

def process_one(path):
    with xr.open_dataset(path) as ds:
        ds = ds.load()
        if "valid_time" in ds.coords:
            ds = ds.rename({"valid_time": "time"})
        vpd = es(ds["t2m"] - 273.15) - es(ds["d2m"] - 273.15)
        ws  = np.sqrt(ds["u10"]**2 + ds["v10"]**2)
        out = xr.Dataset({
            "vpd_monthly_mean_daymax":
                vpd.resample(time="1D").max().resample(time="1MS").mean(),
            "wind_speed_monthly":
                ws.resample(time="1MS").mean(),
        })
        return out.load()

files = sorted(Path("data/era5_3hourly").glob("era5_3h_surface_*.nc"))
monthly = xr.concat([process_one(f) for f in files], dim="time").sortby("time")
monthly = monthly.rename({"time": "valid_time"})
monthly.to_netcdf("data/era5_derived_monthly.nc")
